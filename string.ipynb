# %%
x = input("enter your name ")
y = input(" enter your age")
z = input(" pincode")
print(type
      
      
      (x+y+z))
# Out:
# enter your name  jfgf
#  enter your age 134
#  pincode 44
# <class 'str'>

# %%
x = " krishna pratap singh is btech student"
print(x)
print(type(x))
y = x[9:16]
print(y)
# Out:
#  krishna pratap singh is btech student
# <class 'str'>
# pratap
