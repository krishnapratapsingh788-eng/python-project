# %%
y = [1 ,2,3,[1,2,3]]
b = y[1]
print(b)
# Out:
# 2

# %%
y = 1,2,3,['a','b',['A','B'],6]
b = y[3][2]
print(b)
# Out:
# ['A', 'B']

# %%
# make atm machine
#Deposit
x = int(input("enter deposit amount ="))
Deposit = 0
current_balance = Deposit+x

if x>0:
    print("deposit complete")
else:
    print("invalid inpute")
print("current Balanee =",current_balance)
# Out:
# enter deposit amount = 1
# deposit complete
# current Balanee = 1

# %%
#Withdraw
x = int(input("enter Witrhdrwa amount ="))
balance = 10000
current_balance = balance-x

if x>balance:
    print("insufficient balance")
else:
    print("withdrwa  complete")

print("current Balanee =",current_balance)
# Out:
# enter Witrhdrwa amount = 199
# withdrwa  complete
# current Balanee = 9801

# %%
#### ATM Machine Simulator
print("Welcome to the ATM!")
# initial balance
balance = 0

# deposit function
# User data
user = {
    "101": {
        "name": ["krishna", "Anant", "Akshat"]
        #card_no : 19872635,
        "pin": ["8736", "2146", "2536"]
    }
}

while True:
    card_no = input("Enter your card number")
    if card_no in users:
        pin = input("Enter your PIN: ")
        if pin == user["101"]["pin"]:
            print("PIN verified successfully!")
            name = input("Enter your name: ")
                if name == user["101"]["name"]:
                    print("Name verified successfully")
            #break
        else:
            print("Name does not match. Please try again.")
    else:
        print("Invalid PIN. Please try again.")
def deposit(amount):
    global balance
    if amount > 0:
        balance += amount
        print(f"Deposit successful! Current Balance = {balance}")
    else:
        print("Invalid deposit amount. Please enter a positive value.")


def withdraw(amount):
    global balance
    if amount > balance:
        print(f"Insufficient Balance! Your current balance is {balance}")
    elif amount <= 0:
        print("Invalid withdrawal amount.")
    else:
        balance -= amount
        print(f"Withdrawal successful! Current Balance = {balance}")


def check_balance():
    print(f"Your current balance is {balance}")

def atm():
    
    while True:
        print("\nMenu:")
        print("1. Deposit")
        print("2. Withdraw")
        print("3. Check Balance")
        print("4. Exit")
        
        choice = input("Enter your choice")

        if choice == "1":
            amt = int(input("Enter amount to deposit: "))
            deposit(amt)
        elif choice == "2":
            amt = int(input("Enter amount to withdraw: "))
            withdraw(amt)
        elif choice == "3":
            check_balance()
        elif choice == "4":
            print("Thank you for using our ATM. Goodbye!")
            break
        else:
            print("Invalid choice. Please try again.")


atm()
# Out:
#   Cell In[3], line 10
#     "name": ["krishna", "Anant", "Akshat"]
#             ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
user = {
    "101": {
        "name": "krishna",
        "pin": ["8736"]
    }
    }
print(user["101"]["pin"])
# Out:
# ['8736']

# %%
pin = input("enter your pin")
user = {
    "101": {
        "name": "krishna",
        "pin": "8736"
    }
    }
print(user["101"]["pin"] == pin)
# Out:
# enter your pin 8736
# True

# %%
user = {
    "101": {
        "name": "krishna",
        #card_no : 19872635,
        "pin": "8736"
    }
    
print(user.keys())
# Out:
# dict_keys(['101'])

# %%
user = {
    "101": {
        "name": ["krishna", "Anant", "Akshat"],
        #card_no : 19872635,
        "pin": ["8736", "2146", "2536"]
    }
}


print(user.keys())
print(user["101"]['name'][0])
print(user["101"]['pin'][0])
# Out:
# dict_keys(['101'])
# krishna
# 8736
