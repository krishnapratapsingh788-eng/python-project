# %%
x = 5 
b = 6 
print(str(x+b))
print(int(x))
c= print(str(x+b))
# Out:
# 11
# 5
# 11

# %%
x = 2
print(str(x))
print(int(x))
print(float(x))
print(type(str(x)),(int(x)),float(x))
print("..........\n...........")

c = {"name" : "krishna", "age" : 21}
print(x)
print(type(x))
print("..........\n..........")
x = 2
if x < 6:
    print("y")
else :
    print(false)
a = [1,2,3,4,]
b = [5,6,7,8,]
if a>=b:
    print("ture")
else:
    print("flase")
# Out:
# 2
# 2
# 2.0
# <class 'str'> 2 2.0
# ..........
# ...........
# 2
# <class 'int'>
# ..........
# ..........
# y
# flase
