# %%
a = 5
b = 7
sum = a+b
h = f"sum of {a} and {b} is {sum}"
print(h)
# sum of a and b
# Out:
# sum of 5 and 7 is 12

# %%
s = ['krishna', 'pratap', 'singh']
print(s[0])
# print word form list
# Out:
# krishna

# %%
a = "hello WORLD"
print(str.upper(a))
# upper case
print(str.lower(a))
# lower case
length = len(a)
print(length)
# length 
ss = a.replace(" ","_")
print(ss)
# replace
# Out:
# HELLO WORLD
# hello world
# 11
# hello_WORLD

# %%
# for string 
s = input("enter a string:")
a = s[::-1]
if a == s:
    print(s,"is a palinddrome.")
else:
    print(s,"is not a palindrome.")
# Out:
# enter a string: krishna
# krishna is not a palindrome.

# %%
a = input("enter your name "),input("enter your number "),input("enter your father name ")
b = a[0]
print(b)
print(a[1]) 
print(a)
# take user input and extract word form user input
# Out:
# enter your name  krishna
# enter your number  dhshfdh
# enter your father name  fghudhgf
# krishna
# dhshfdh
# ('krishna ', 'dhshfdh', 'fghudhgf')

# %%
x = "DaD"
y = x[::-1]
print(x == y)
# check palindrone
# Out:
# True

# %%
s = 'krishna is boy'
y = s.split()
print(y) 
# spilt sentence
# Out:
# ['krishna', 'is', 'boy']
