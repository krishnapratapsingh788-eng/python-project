# %%
x = float(input("enter exam score 1"))
b = float(input("enter exam score 2"))
c = float(input("enetr exam score 3"))
z = x+b+c
y = z/3
print(y)
if 90>=y and y<100:
    print('A')
elif 80>=y and y<90:
    print('B')
elif 70>=y and y<80:
    print('c')
elif 60>=y and y<70:
    print('D')
elif 60<y:
    print("fale")
# Out:
# enter exam score 1 50
# enter exam score 2 50
# enetr exam score 3 50
# 50.0
# A

# %%
a= 4 / 2
print(a)
# Out:
# 2.0
