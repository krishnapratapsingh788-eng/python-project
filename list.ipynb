# %%
p = [2,3,4,5,6]
even = [i for i in p if i%2 == 0]
print(even)
# Out:
# [2, 4, 6]

# %%
odd = [i for i in p if i%2!= 0]
print(odd)
# Out:
# [3, 5]

# %%
cube = [ i*3 for i in p]
print(cube)
# Out:
# [6, 9, 12, 15, 18]

# %%
t1 = [5,3,4,6,8,10]
l = []
for i in t1:
    if i%2 == 0:
        l.append(i)
        print(i)
# Out:
# 4
# 6
# 8
# 10
