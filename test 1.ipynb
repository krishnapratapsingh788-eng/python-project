# %%
x = int(input("enetr a integer")

# %%
n = int(input("enter a number"))
if n%2 ==2:
    print(f"{n}) is even.")
elif:
    print(f"{n} is odd")
elif n>0:
    print(f"{n} is positive ")
elif n<0:
    print(f"{n} is positive ")
else:
    print(f"{n} is zero ")
# Out:
#   Cell In[2], line 4
#     elif:
#         ^
# SyntaxError: invalid syntax
